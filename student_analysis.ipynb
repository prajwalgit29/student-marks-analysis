# %%
import pandas as pd



df = pd.DataFrame({
    "Student_ID":[101,102,103,104,105,106,107,108,109,110],
    "Name":["Amit","Priya","Rahul","Sneha","Arjun","Kiran","Neha","Ravi","Pooja","Manoj"],
    "Age":[20,21,22,20,23,21,22,20,21,22],
    "Course":["Python","Python","Data Science","Python","Data Science",
              "Python","Data Science","Python","Data Science","Python"],
    "Marks":[85,92,78,88,95,67,81,73,89,90]
})

df.to_csv("students.csv", index=False)

print("students.csv created successfully")
# Out:
# students.csv created successfully

# %%
import os

print(os.getcwd())
# Out:
# C:\Users\USER

# %%
df=pd.read_csv("students.csv")

# %%
df
# Out:
#    Student_ID   Name  Age        Course  Marks
# 0         101   Amit   20        Python     85
# 1         102  Priya   21        Python     92
# 2         103  Rahul   22  Data Science     78
# 3         104  Sneha   20        Python     88
# 4         105  Arjun   23  Data Science     95
# 5         106  Kiran   21        Python     67
# 6         107   Neha   22  Data Science     81
# 7         108   Ravi   20        Python     73
# 8         109  Pooja   21  Data Science     89
# 9         110  Manoj   22        Python     90

# %%
df.head()
# Out:
#    Student_ID   Name  Age        Course  Marks
# 0         101   Amit   20        Python     85
# 1         102  Priya   21        Python     92
# 2         103  Rahul   22  Data Science     78
# 3         104  Sneha   20        Python     88
# 4         105  Arjun   23  Data Science     95

# %%
df.head(3)
# Out:
#    Student_ID   Name  Age        Course  Marks
# 0         101   Amit   20        Python     85
# 1         102  Priya   21        Python     92
# 2         103  Rahul   22  Data Science     78

# %%
df.tail()
# Out:
#    Student_ID   Name  Age        Course  Marks
# 5         106  Kiran   21        Python     67
# 6         107   Neha   22  Data Science     81
# 7         108   Ravi   20        Python     73
# 8         109  Pooja   21  Data Science     89
# 9         110  Manoj   22        Python     90

# %%
df.tail(2)
# Out:
#    Student_ID   Name  Age        Course  Marks
# 8         109  Pooja   21  Data Science     89
# 9         110  Manoj   22        Python     90

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Student_ID  10 non-null     int64
#  1   Name        10 non-null     object
#  2   Age         10 non-null     int64
#  3   Course      10 non-null     object
#  4   Marks       10 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 532.0+ bytes

# %%
df.describe()
# Out:
#        Student_ID        Age      Marks
# count    10.00000  10.000000  10.000000
# mean    105.50000  21.200000  83.800000
# std       3.02765   1.032796   8.929352
# min     101.00000  20.000000  67.000000
# 25%     103.25000  20.250000  78.750000
# 50%     105.50000  21.000000  86.500000
# 75%     107.75000  22.000000  89.750000
# max     110.00000  23.000000  95.000000

# %%
df['Age']
# Out:
# 0    20
# 1    21
# 2    22
# 3    20
# 4    23
# 5    21
# 6    22
# 7    20
# 8    21
# 9    22
# Name: Age, dtype: int64

# %%
df['Age'].max()
# Out:
# np.int64(23)

# %%
df['Age'].min()
# Out:
# np.int64(20)

# %%
df['Marks']
# Out:
# np.int64(838)

# %%
df['Marks'].mean()
# Out:
# np.float64(83.8)

# %%
avg=df['Marks'].mean()

# %%
print("Averaghe is:",avg)
# Out:
# Averaghe is: 83.8

# %%
df[df['Marks']>90]
# Out:
#    Student_ID   Name  Age        Course  Marks
# 1         102  Priya   21        Python     92
# 4         105  Arjun   23  Data Science     95

# %%
high_scorers = df[df["Marks"] > 80]
print(high_scorers)
# Out:
#    Student_ID   Name  Age        Course  Marks
# 0         101   Amit   20        Python     85
# 1         102  Priya   21        Python     92
# 3         104  Sneha   20        Python     88
# 4         105  Arjun   23  Data Science     95
# 6         107   Neha   22  Data Science     81
# 8         109  Pooja   21  Data Science     89
# 9         110  Manoj   22        Python     90

# %%
df[df['Course']=='Python']
# Out:
#    Student_ID   Name  Age  Course  Marks
# 0         101   Amit   20  Python     85
# 1         102  Priya   21  Python     92
# 3         104  Sneha   20  Python     88
# 5         106  Kiran   21  Python     67
# 7         108   Ravi   20  Python     73
# 9         110  Manoj   22  Python     90

# %%
len(high_scorers)
# Out:
# 7

# %%
len(df[df['Course']=='Python'])
# Out:
# 6

# %%
df['Grade']=df['Marks'].apply(
    lambda x:"A" if x>=90 else
             "B" if x>80 else
             "c"
               
    )

# %%
df
# Out:
#    Student_ID   Name  Age        Course  Marks Grade
# 0         101   Amit   20        Python     85     B
# 1         102  Priya   21        Python     92     A
# 2         103  Rahul   22  Data Science     78     c
# 3         104  Sneha   20        Python     88     B
# 4         105  Arjun   23  Data Science     95     A
# 5         106  Kiran   21        Python     67     c
# 6         107   Neha   22  Data Science     81     B
# 7         108   Ravi   20        Python     73     c
# 8         109  Pooja   21  Data Science     89     B
# 9         110  Manoj   22        Python     90     A
